# %%
import pandas as pd
import os

# %%
file_path1 = os.path.join("JC-201907-citibike-tripdata.csv")
file_path2 = os.path.join("JC-201908-citibike-tripdata.csv")
file_path3 = os.path.join("JC-201909-citibike-tripdata.csv")

# %%
df1 = pd.read_csv(file_path1)

# %%
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
df2 = pd.read_csv(file_path2)

# %%
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
df3 = pd.read_csv(file_path3)

# %%
df3.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           145   00:37.7  03:03.0              3640     Journal Square
# 1           212   03:00.6  06:33.3              3194    McGinley Square
# 2           569   07:13.0  16:42.9              3214   Essex Light Rail
# 3          1380   07:25.3  30:26.2              3214   Essex Light Rail
# 4          1346   07:56.5  30:22.5              3214   Essex Light Rail
#
#    start station latitude  start station longitude  end station id  \
# 0               40.733670               -74.062500            3206
# 1               40.725340               -74.067622            3679
# 2               40.712774               -74.036486            3184
# 3               40.712774               -74.036486            3792
# 4               40.712774               -74.036486            3792
#
#              end station name  end station latitude  end station longitude  \
# ...

# %%
dfall = pd.concat([df1,df2,df3])
dfall
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1               434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2               251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3               636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4               623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
# 5               779  2019-07-01 00:04:34.1330  2019-07-01 00:17:34.0800
# 6               123  2019-07-01 00:05:23.5820  2019-07-01 00:07:27.5070
# 7               381  2019-07-01 00:17:31.7600  2019-07-01 00:23:53.0680
# 8               665  2019-07-01 00:31:08.6430  2019-07-01 00:42:14.2910
# 9               509  2019-07-01 01:40:25.3990  2019-07-01 01:48:54.8780
# 10             1336  2019-07-01 01:45:16.3750  2019-07-01 02:07:32.6490
# 11              281  2019-07-01 01:59:40.3030  2019-07-01 02:04:21.6510
# ...

# %%
dfall.to_csv("citibike.csv")
